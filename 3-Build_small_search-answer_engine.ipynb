# %% [markdown]
# **Author:** Carolina Gonçalves, carolina.goncalves@research.fchampalimaud.org
#
# **Scope**: A simple and personalized use case of RAG, joining search methods with LLMs. The goal is to get a basic understanding of how systems like search-answer engines might work under the hood.

# %% [markdown]
# **First of all**, change runtime type to GPU, before you start. This will make the LLM answering process faster.

# %% [markdown]
# # (Just run):
#
# 1. Install packages
# 2. Import packages; access to google drive
# 3. All code needed for the rest of the notebook.

# %%
# !pip install -U sentence-transformers
# !pip install --upgrade transformers
# !pip install -U bitsandbytes
# !pip install pymupdf
# !pip install rank_bm25
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.4.0+cu121)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (3.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (0.43.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.4.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.10/dist-packages (1.24.10)
# Requirement already satisfied: PyMuPDFb==1.24.10 in /usr/local/lib/python3.10/dist-packages (from pymupdf) (1.24.10)
# Requirement already satisfied: rank_bm25 in /usr/local/lib/python3.10/dist-packages (0.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rank_bm25) (1.26.4)

# %%
import fitz  # PyMuPDF: https://pymupdf.readthedocs.io/en/latest/tutorial.html#extracting-text-and-images
import pandas as pd
import os
import re
from IPython.display import Markdown, display
import numpy as np
import textwrap
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from rank_bm25 import BM25Okapi
import time
# Use a pipeline as a high-level helper
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import random
import torch

from google.colab import drive
# Connect to drive: this will enable you to save content in your drive and also load it from there
drive.mount('/content/drive', force_remount=True)

# Set a random seed
random_seed = 42
random.seed(random_seed)

# Set a random seed for PyTorch (for GPU as well)
torch.manual_seed(random_seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(random_seed)
# Out:
# Mounted at /content/drive

# %%
## PDF Reader and Index

def save_results_to_txt(all_docs, pdf_names, folder_path, FILENAME):
  '''
  Function to save text retrieved from the PDF to a txt file

  folder_path (str): folder where you want to save it
  FILENAME (str): name of the file where you want to save the text
  all_docs (list of dicts): where the text of each of your documents is stored
  pdf_names (list of str): list of your documents names (as they are stored in your drive)
  '''
  with open(folder_path + FILENAME, "w") as f: #open file where you want to save your PDF
    for i, doc in enumerate(all_docs): #Go through all the documents, one at a time
      if bool(doc): # if text was retrieved from this doc
        f.write(f"{i} URL: {pdf_names[i]}\n")
        for title, text in doc.items(): # Go through each sub-section (title: paragraphs)
          f.write(f"{title}:\n") #Writing the title
          for paragraph in text:
            f.write(paragraph + "\t") #Writing each paragraoh
          f.write("\n")
        f.write("\n\n")
  f.close() #close the file

def contains_titles_to_ignore(paragraph, keywords = ["content", "index", "appendix", "figures", "contacts"]):
  ''' This checks is any of those keywords is present in the given paragraph.
  The goal here is to detect pages that have the "Appendix", "Index of Contents",...
  And ignore that '''
  return any(keyword in paragraph.strip().lower() for keyword in keywords)


def extract_pdf_content(pdf_file_path, max_title_size=20, max_text_size=12, min_text_size=9):
  '''
  Extracts and parses text from a pdf_file.
  Details being IGNORED:
      page numeration;
      pages with big titles (with font_size > max_title_size) that have the words "Appendix", "Index of Contents",...;
      headers and foot notes (font_size < min_text_size);
      images;
      bigger titles (font_size > max_title_size);
      lines that just have numbers or weird symbols and no text.

  pdf_file_path (str): path to the pdf file
  max_title_size (int): maximum size allowed for a title to be retrieved/stored.
                      if font_size >= max_title_size, text will be ignored.
  max_text_size (int): maximum size allowed for a paragraph.
                  if font_size > max_text_size, text will be considered a title.
  min_text_size (int): minimum size allowed for a paragraph to be retrieved/stored.
                  if font_size <= min_text_size, text will be ignored.

  returns content_list (dict): a dictionary with the pdf's text organized by title and paragraphs as follows
          content_list = {
            "Title 1": ["Paragraph 1", "Paragraph 2", ...],
            "Title 2": ["Paragraph 1", "Paragraph 2", ...],
            ...
          }
  '''
  doc = fitz.open(pdf_file_path) # Open the PDF file

  content_list, all_titles = {}, [] # Initialize an empty list to store the content of each page
  bold_flag=8   # this is a flag from PyMuPDF package that sinalizes when a text
                # is bold (flag > 8). (DON'T NEED TO CHANGE THIS)

  # Iterate over each page and extract text
  for page_num in range(len(doc)):
      page = doc.load_page(page_num)  # Load the page
      text = page.get_text("dict")['blocks'] # get text blocks (= paragraphs).

      for block in text: # Iterate over blocks of text
          if 'lines' in block:  # Check if the block contains text lines
              paragraph = ""
              font_size, flag, count = 0, 0, 0
              for line in block['lines']: # get all lines inside a block
                  for span in line['spans']: # get all "sub-lines"
                      if len(span['text'].strip()) > 1: # Ignore empty spans
                        saved_span = span
                        paragraph += span['text']  # Get the actual text
                        font_size += span['size']  # font size for each span
                        flag += span["flags"] # flag of each span just to know if
                                    # we are dealing with some kind of sub-title
                                    # if so, all text in this block would have an
                                    # average high flag (meaning, for e.g., bold + superscript)
                        count += 1

              if len(paragraph.strip())==0: # if this paragraph == empty spaces
                continue # continue to other block that actually has text

              else:
                font_size /= count # compute the average font_size for the paragraph
                flag /= count

                # ignoring FULL page with index of contents, figues, appendix,...
                if font_size > max_text_size and contains_titles_to_ignore(paragraph):
                  break #ignore page; jumps back in the code to go to next page_num

                # Ignoring headers and foot notes based on font_size
                if font_size < max_title_size and font_size > min_text_size:
                  # Get titles: font_size > max_text_size or bold (flag>8) with a slightly lower font_size
                  if font_size > max_text_size or (font_size >= (max_text_size-2) and flag > bold_flag):
                    # paragraph is a title

                    # CORRECT FOR MISTAKES: (before adding a new title)
                    # if we previously just added a title, but has no paragraphs
                    if bool(content_list) and len(content_list[all_titles[-1]]) == 0:
                      # check if we mistankenly ignored some paragraph that is not
                      # big enough to be a title and add it back
                      if backup_text[1] <= max_text_size:
                        # correct for possible missing relevant text because of variations in font size
                        content_list[all_titles[-1]].append(backup_text[0])
                      else: # or if it's just an isolated (sub)title, will delete it
                        content_list.pop(all_titles[-1])

                    # now, we can start the new section of the doc with the new title
                    content_list[paragraph.strip()] = [] # paragraph here is the title
                    all_titles.append(paragraph.strip())

                  # Get normal text paragraphs
                  else:
                    if not bool(content_list): # if the pdf does not start with a title
                      content_list["First paragraph"] = [] # add a fake title
                      all_titles.append(["First paragraph"])

                    # Check if the first letter of the text is capital letter
                    first_letter = next((char for i, char in enumerate(paragraph) if char.isalpha()), -1)
                    if first_letter == -1: # couldn't find any letter
                      continue # ignore and continue to other block that actually has text

                    elif first_letter.isupper(): #new paragraph if it starts with capital letter
                      # append new paragraph to previous title; remove bulletpoint signal, if it's there one
                      content_list[all_titles[-1]].append(paragraph[1:].strip() if paragraph.startswith('•') else paragraph.strip())

                    else: # if it starts with lower case, it's the continuation of the
                      # previous paragraph (e.g: when same paragraph extends across pages)
                      if len(content_list[all_titles[-1]]) == 0:
                        # in case this is the first paragraph in a title
                        content_list[all_titles[-1]] = [""]
                      content_list[all_titles[-1]][-1] += " " + (paragraph[1:] if paragraph.startswith('•') else paragraph.strip())

                else:
                  # CORRECT FOR MISTAKES: keep record of the ignored text for
                  # one iteration longer, in case this might be normal paragraphs following
                  # some sub-title or box of highlights that got ignored, because it has
                  # a smaller font_size than 9
                  backup_text = (paragraph, font_size)

  doc.close() # Close the PDF file
  return content_list

def scrape_pdfs(folder_path, pdfs_list, max_title_size=20, max_text_size=12, min_text_size=9):
  '''
  Gets text from multiple pdf files, as long as they are in the same folder.

  folder_path (str): path to folder with all pdfs
  pdfs_list (list of str): list of pdfs' filenames to be retrieved
  max_title_size (int): maximum size allowed for a title to be retrieved/stored.
                      if font_size >= max_title_size, text will be ignored.
  max_text_size (int): maximum size allowed for a paragraph.
                  if font_size > max_text_size, text will be considered a title.
  min_text_size (int): minimum size allowed for a paragraph to be retrieved/stored.
                  if font_size <= min_text_size, text will be ignored.

  returns all_docs_text (list of dicts): a list with a  a dictionary per pdf
         organized by title and paragraphs as follows
          dict_pdf_0 = {
            "Title 1": ["Paragraph 1", "Paragraph 2", ...],
            "Title 2": ["Paragraph 1", "Paragraph 2", ...],
            ...
          }
  '''
  all_docs_text = []
  for idx, file_name in enumerate(pdfs_list):
    assert file_name.endswith(".pdf"), "File must be a pdf (end with '.pdf')"
    print(f"Fecthing text from pdf {idx}...")
    text = extract_pdf_content(os.path.join(folder_path, file_name),
                               max_title_size, max_text_size, min_text_size)
    all_docs_text.append(text)

  return all_docs_text

def extract_font_info(folder_path, file_name, n_pages=6):
  '''
  Same logic as function "extract_pdf_content", but only serves
  to check the font_sizes of some pages (n_pages) and use it to adjust the
  parameters of that function, if necessary.
  '''
  doc = fitz.open(os.path.join(folder_path, file_name))

  for page_num in range(len(doc)):
      page = doc.load_page(page_num)

      # Extract all text information including fonts and sizes
      text_instances = page.get_text("dict")["blocks"]

      for block in text_instances:
        if 'lines' in block:
          for line in block.get("lines", []):
              for span in line.get("spans", []):
                  text = span.get("text")
                  font_size = span.get("size")
                  font_name = span.get("font")
                  print(f"Page {page_num + 1}: '{text}' \n-> Font: {font_name}, Size: {font_size}\n")

      if page_num > n_pages:
        break

def show_your_index(all_docs, folder_path):
  '''
  Simple index to know where to find each title and paragraph
  (to which document/link in our list of pdfs/search results does it belong to)
  '''
  all_titles = {"Titles": [], "Doc_IDs": []}
  all_para = {"Paragraphs": [], "Doc_IDs": [], "Titles": []}
  for id, doc in enumerate(all_docs):
    if bool(doc):
      for title, text in doc.items():
        all_titles["Titles"].append(title)
        all_titles["Doc_IDs"].append(id)
        for paragraph in text:
          all_para["Paragraphs"].append(paragraph)
          all_para["Doc_IDs"].append(id)
          all_para["Titles"].append(title)

  df = pd.DataFrame.from_dict(all_titles)
  df_para = pd.DataFrame.from_dict(all_para)

  df.to_csv(folder_path + "titles_index.csv")
  df_para.to_csv(folder_path + "paragraphs_index.csv")
  return df, df_para






## Pre-processing and ranking w/ BM25

nltk.download("stopwords")
stop_words = set(stopwords.words("english"))  # nlkt
print(stop_words)

porter_stemmer = PorterStemmer()

def preprocess(text, stem=False, print_tokens=False):
  # Tokenization and lowercasing; also ignore punctuation
  tokens = re.findall(r"\w+", text.lower()) #separating words

  # Remove noisy terms including stopwords from indexing
  filtered_tokens = [
      token
      for token in tokens
      if token not in stop_words
  ]
  # Converting words to their cannonical form
  if stem:
    filtered_tokens = [
        porter_stemmer.stem(token) for token in filtered_tokens
    ]
  if print_tokens:
    print(filtered_tokens)
  return filtered_tokens

def search_wBM25(query, processed_docs, original_docs, stem=False, print_keywords=False, k=1.2, b=0.75, N=3):
    '''
    Implements BM25 algortihm for ranking documents based on their relevance to a given query.
    k and b are hyperparameters that control for term frequency saturation and document length normalization, respectively.
    Returns the top-3 most relevant documents to the query, order by relevance (BM25 score).
    '''
    tini = time.time()
    # Initialize BM25 with the tokenized and pre-processed corpus
    # IDF will be computed based on this corpus
    bm25 = BM25Okapi(processed_docs, k1=k, b=b)
    # Pre-process the query as the processed_docs (stem=True if the docs were stemmed)
    # Then, use BM25 to score each document based on its similarity to the query
    bm25_scores = bm25.get_scores(preprocess(query, stem=stem, print_tokens=print_keywords))
    top_n = np.argpartition(bm25_scores, -N)[-N:] #select the top 3 most matched docs to the query
    bm25_hits = [{'corpus_id': idx, 'score': bm25_scores[idx]} for idx in top_n]
    if len(bm25_hits)>1:
      bm25_hits = sorted(bm25_hits, key=lambda x: x['score'], reverse=True) #sorting the passages by their score
    tout = time.time()

    print(f"Total time spent searching: {tout-tini}s")
    return bm25_hits[:N]

def ranking(question, docs, N=3):
  tokenized_text = [preprocess(t, stem=True) for t in docs]
  hits = search_wBM25(question, tokenized_text, docs, stem=True,
                      print_keywords=False, k=1.2, b=0.75, N=N)

  matches = []
  for result in hits:
    if result["score"] > 0:
      t = docs[result['corpus_id']]
      print("{:.3f}\t{}\n".format(result['score'], t))
      matches.append(t)

  if len(matches) == 0:
    print("No matches found with score > 0")
  return matches


## Manual Selection

def select_full_docs(all_docs_pdf, doc_ids):
  selected_docs = []
  for i in doc_ids:
    plain_text = []
    for title, text in all_docs_pdf[i].items():
      plain_text.append(title)
      for para in text:
        plain_text.append(para)
    selected_docs.extend(plain_text)
  return selected_docs

def select_by_title(all_docs_pdf, titles, title_index):
  selected_titles_text = []
  for title in titles:
    row = title_index[title_index['Titles'] == title]
    assert not row.empty, "You gave a title that does not exist"
    doc_ids = row["Doc_IDs"].values
    for id in doc_ids:
      selected_titles_text.extend(all_docs_pdf[id][title])
  return selected_titles_text



## Choose how to select

def estimate_tokens(text):
  words = re.findall(r"\w+", text) #separating words
  # Rule of thumb: 100 tokens ~= 75 words
  n_tokens = len(words) * 100/75
  return n_tokens

def select(all_docs_pdf, to_select, title_index, para_index,
           mode="manually", by="doc", N=3, question=None):
  assert mode in ["manually", "ranking"], "Mode has to be one of: 'manually' or 'ranking'"
  if mode == "manually":
    assert by in ["doc", "title", "paragraph"], "By has to be one of: 'doc' or 'title' or 'paragraph'"
    assert len(to_select) > 0, "You need to select at least one document/title/paragraph"
  else:
    assert by in ["title", "paragraph"], "For ranking, By has to be one of: 'title' or 'paragraph'"
    assert question is not None, "You need to provide a question to rank."

  if mode=="manually":
    if by=="doc":
      selected_text = select_full_docs(all_docs_pdf, to_select)

    elif by=="title":
      selected_text = select_by_title(all_docs_pdf, to_select, title_index)

    elif by=="paragraph":
      selected_text = list(paragraph_index.loc[to_select, :]['Paragraphs'])

  elif mode=="ranking":
    if by=="title":
      selected_titles = ranking(question, list(title_index["Titles"]), N)
      if len(selected_titles) > 0: #get the paragraphs for the selected titles
        selected_text = select_by_title(all_docs_pdf, selected_titles, title_index)
      else:
        selected_text = []
    elif by=="paragraph":
      selected_text = ranking(question, list(para_index["Paragraphs"]), N)

  if len(selected_text) == 0:
    print("No matches found")
  else:
    total_no_tokens = 0
    print(f" Selected text: \n")
    for t in selected_text:
      total_no_tokens += estimate_tokens(t)
      print(textwrap.fill(t, width=100))
      print("\n")
  print(f"\n Estimated number of tokens: {total_no_tokens}")
  return selected_text





## LOAD LLM model

def load_LLM_model(model_id, token):
  # Configure quantization
  # We'll also use [*quantization*]
  # (https://huggingface.co/docs/optimum/concept_guides/quantization)
  # to make inference faster. If we don't use it, we can't fit the model in colab's GPU.
  quant_config = BitsAndBytesConfig(
      load_in_8bit=True,  # Enable 8-bit quantization
      llm_int8_threshold=6.0,  # Optional: Adjust this threshold to balance accuracy and performance
                              # A lower value can result in more aggressive quantization, potentially speeding up
                              # inference further at the cost of some accuracy.
  )

  # Load the model with quantization
  model = AutoModelForCausalLM.from_pretrained(model_id,
                                              token=token,
                                              device_map="auto",
                                              quantization_config=quant_config)

  #https://huggingface.co/transformers/v3.0.2/main_classes/pipelines.html
  pipe = pipeline("text-generation",
                  model=model,
                  tokenizer=model_id,
                  token=token,
                  )
  return pipe

## Write prompt and generate answer with LLM

def write_prompt(instructions, context=[], question=""):
  if len(context)>0:
    results_text = ""
    for p_id, content in enumerate(context):
      results_text += f'''[{p_id}] {content}\n'''

    if question == "":
      prompt_template = f'''{instructions}
      Web search results:\n{results_text}'''
    else:
        prompt_template = f'''{instructions}
        Web search results:\n{results_text}
        Query: {question}'''

  else: #no context given
    if question == "":
      prompt_template = f'''{instructions}'''
    else:
      prompt_template = f'''{instructions}
      Query: {question}'''

  wrapped_text = textwrap.fill(prompt_template, width=150)
  print(f"FULL PROMPT:\n {wrapped_text}\n")

  print(f" ******* ESTIMATED NUMBER OF TOKENS: {estimate_tokens(prompt_template)}")
  return prompt_template

def generative_response(llm_pipe, prompt, temperature=1,
                        max_length=8000, instruction_tunned=True):
  if instruction_tunned:
    messages = [
      {"role": "user", "content": prompt},
    ]
  else:
    #if it's just a foundational model, won't need or accept the messages format above
    messages = prompt
  # Generate text using the LLM
  pipeline_output = llm_pipe(messages,
                        temperature=temperature,
                        max_length=max_length, # Maximum number of tokens in the generated output
                        #if False,  model will generate the most probable sequence (greedy decoding)
                        #num_return_sequences=1,
                        truncation=True,
                        )
  return pipeline_output[0]["generated_text"][-1]["content"]
# Out:
# {'he', 'him', 'after', "you're", "it's", 'between', 'will', 'll', 'only', 'what', 'doesn', 'yourself', 'haven', "haven't", 'she', 'm', 'having', "you'd", 'then', 'been', 'an', "should've", 'needn', 'this', 'or', 'any', 'out', 'but', 'above', 'again', 'has', 'very', "mightn't", 'because', 'of', 'does', 'aren', 'these', 'was', 'it', 'that', 'o', 'have', 'further', 'no', 'them', 'd', 'and', 'wasn', 'why', 'their', 'on', 'each', 'is', "don't", "wasn't", 'not', 'other', 'did', 'how', 'if', 'we', 'just', 'my', 'hadn', 'shouldn', 'who', 'where', 'once', 'against', "doesn't", 'during', 'both', 'won', 'over', 'until', 'should', "mustn't", 'had', 'below', 'when', 'yourselves', "isn't", 'were', 've', "that'll", 'shan', 'most', 'at', 'about', 'weren', "needn't", 'mightn', 'those', 'into', "shan't", 'couldn', 'up', 'in', 'off', 'before', 'me', "didn't", "hadn't", 'ours', 'with', 'nor', 'be', 'to', 'doing', 'more', 'ma', "won't", 'itself', 'all', 'herself', "she's", 'through', 'too', "aren't", 'themselves', 'down', 'ain', 'y', 'his', 'own', "you'll", 'our', "you've", 'her', 'by', 'some', 'a', "couldn't", 'theirs', 'am', 'while', 'being', 'do', 'are', 'same', 'i', 'than', 'such', "shouldn't", 're', 'under', 'your', 'for', 's', "weren't", 'hers', 'its', 'isn', 'can', 'himself', 'as', 'mustn', 'here', 'hasn', "wouldn't", 'yours', 'they', 'few', 'didn', 'whom', 'from', 'now', 'so', 'you', "hasn't", 'myself', 'which', 't', 'the', 'ourselves', 'there', 'don', 'wouldn'}
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # Use it here!

# %% [markdown]
# Before starting: **CHANGE the second part of *folder_path*** (after "+") to the location in your drive where this notebook is.

# %%
# set the folder where the data and notebooks are inside your drive
folder_path = "/content/drive/" + "Shareddrives/AI_Law_Course_2024/Content/"
print(f"You're notebook and files should be in this folder: {folder_path}")
# Out:
# You're notebook and files should be in this folder: /content/drive/Shareddrives/AI_Law_Course_2024/Content/

# %% [markdown]
# **CHANGE ALSO** the Runtime of your notebook to GPU if you want to use LLMs (it will be faster to run them).
#
#
# Now, you can start reading your pdf's.

# %% [markdown]
# ## 1. Get your pdfs:
#
# * Upload the pdfs you want to use in this drive's folder (*folder_path*).
# * Then write the names of each pdf file to be searched through, like this:
#
# > pdfs_list = ["pdf1.pdf", "pdf2.pdf"]

# %%
pdfs_list = ["EU_QA.pdf"] # WRITE here your pdf file names
all_docs_pdf = scrape_pdfs(folder_path, pdfs_list,
                           max_title_size=20, max_text_size=12,
                           min_text_size=9)

# Save pdf texts to a txt file
FILENAME_PDF = "retrieved_docs_pdf.txt"
save_results_to_txt(all_docs_pdf, pdfs_list, folder_path, FILENAME_PDF)
# Out:
# Fecthing text from pdf 0...

# %% [markdown]
# * These are the rest of the parameters for the function:
#   - folder_path (str): path to folder with all pdfs
#   - max_title_size (int): maximum size allowed for a title to be retrieved/stored.
#                       if font_size >= max_title_size, text will be ignored.
#   - max_text_size (int): maximum size allowed for a paragraph.
#                   if font_size > max_text_size, text will be considered a title.
#   - min_text_size (int): minimum size allowed for a paragraph to be retrieved/stored.
#                   if font_size <= min_text_size, text will be ignored.
#
#
#
# **If there's any text that is being OMMITED in one pdf**, you can run the following cell to check the font_size of some pages of that pdf and alter the values above. Otherwise, just ignore!

# %%
pdf_name = pdfs_list[0]
extract_font_info(folder_path, pdf_name, n_pages=6)
# Out:
# Page 1: ' '
# -> Font: Verdana-Italic, Size: 8.039999961853027
#
# Page 1: ' '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 1: ' '
# -> Font: TimesNewRomanPSMT, Size: 0.9599999785423279
#
# Page 1: ' '
# -> Font: TimesNewRomanPSMT, Size: 12.0
#
# Page 1: ' '
# -> Font: TimesNewRomanPSMT, Size: 12.0
#
# Page 1: 'The European Union: Questions and Answers '
# -> Font: PalatinoLinotype-Bold, Size: 21.959999084472656
#
# Page 1: 'Updated January 26, 2024 '
# -> Font: PalatinoLinotype-Roman, Size: 14.039999961853027
#
# Page 1: 'Congressional Research Service '
# -> Font: PalatinoLinotype-Bold, Size: 9.960000038146973
#
# Page 1: 'https://crsreports.congress.gov '
# -> Font: PalatinoLinotype-Roman, Size: 9.960000038146973
#
# Page 1: 'RS21372 '
# -> Font: PalatinoLinotype-Roman, Size: 9.960000038146973
#
# Page 2: ' '
# -> Font: TimesNewRomanPSMT, Size: 12.0
#
# Page 2: 'Congressional Research Service '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 2: ' '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 2: 'SUMMARY '
# -> Font: Calibri-Bold, Size: 14.039999961853027
#
# Page 2: ' '
# -> Font: TimesNewRomanPS-BoldMT, Size: 14.039999961853027
#
# Page 2: 'The European Union: Questions and Answers '
# -> Font: Calibri-Bold, Size: 20.040000915527344
#
# Page 2: 'The European Union (EU) is a political and economic partnership that represents a unique form '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'of cooperation among sovereign countries. The EU is the latest stage in a process of integration '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'begun after World War II, initially by six Western European countries, to foster interdependence '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'and make another war in Europe unthinkable. The EU currently consists of 27 member states, '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'including most of the countries of Central and Eastern Europe, and has helped to promote peace, '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'stability, and economic prosperity throughout the European continent. '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'How the EU Works '
# -> Font: Calibri-Bold, Size: 12.0
#
# Page 2: 'The EU has been built through a series of binding treaties. Over the years, EU member states have harmonized laws and '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'adopted common policies on an increasing number of economic, social, and political issues. EU members share a customs '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'union; a single market in which capital, goods, services, and people move freely; a common trade policy; and a common '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'agricultural policy. Twenty EU member states use a common currency (the euro), and 23 members participate in the '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'Schengen area of free movement in which internal border controls have been eliminated. In addition, the EU has been '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'developing a Common Foreign and Security Policy (CFSP), which includes a Common Security and Defense Policy (CSDP), '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'and pursuing cooperation in the area of Justice and Home Affairs (JHA) on common internal security challenges. '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'Challenges Facing the EU '
# -> Font: Calibri-Bold, Size: 12.0
#
# Page 2: 'The EU is generally considered a cornerstone of European stability and prosperity, but the bloc is grappling with several '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'challenges. The EU has demonstrated solidarity in responding to Russia’s war against Ukraine (launched in February 2022), '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'but the conflict has raised significant security concerns. The war also has galvanized debate on several long-standing EU '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'initiatives, including related to EU defense, energy and climate policies, and EU enlargement. Other key issues facing the EU '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'include democratic backsliding in some member states, the presence of populist and to some extent anti-EU political parties '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'throughout the bloc, managing relations with the United Kingdom (UK) following its exit from the EU in January 2020 '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: '('
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'Brexit'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 9.960000038146973
#
# Page 2: '), ongoing migration concerns, and complex relations with China. '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'U.S.-EU Relations '
# -> Font: Calibri-Bold, Size: 12.0
#
# Page 2: 'Successive U.S. Administrations and many Members of Congress have supported the European integration project since its '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'inception in the 1950s as a means to prevent another catastrophic conflict on the European continent and to foster democratic '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'allies and strong trading partners. Today, the United States and the EU have a dynamic political partnership and share a huge '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'trade and investment relationship. U.S. and EU officials traditionally have viewed the partnership as mutually beneficial. At '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'the same time, U.S.-EU policy differences on a range of foreign policy and economic issues emerge periodically. During the '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'Trump Administration, U.S.-EU relations faced considerable strain given President Trump’s criticisms of the EU and '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'numerous U.S.-EU policy divisions. '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'President Biden has committed to partnering with the EU on a wide range of global concerns, and the conflict in Ukraine has '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'bolstered U.S.-EU ties. The United States and the EU have demonstrated steadfast support for Ukraine’s territorial integrity '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'and have cooperated extensively in imposing sanctions on Russia and other responses. Resolving U.S.-EU trade disputes and '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'promoting technological cooperation also have been priorities for the Biden Administration. However, new U.S. tax subsidies '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'for clean energy technologies (in P.L. 117-169, commonly referred to as the Inflation Reduction Act of 2022) have generated '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'tensions with the EU. Other issues, including managing relations with China and responding to challenges related to the 2023 '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'Israel-Hamas conflict, also may test the U.S.-EU partnership. EU concerns persist about ongoing U.S. political polarization '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'and whether a future U.S. Administration would maintain current U.S. policies toward Russia, Ukraine, and the EU. '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'This report serves as a primer on the EU. It also discusses U.S. relations with the EU that may be of interest to Congress. For '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'more information, see CRS In Focus IF12302, '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'U.S.-European Relations in the 118th Congress'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 9.960000038146973
#
# Page 2: '. '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'RS21372 '
# -> Font: Calibri, Size: 14.039999961853027
#
# Page 2: 'January 26, 2024 '
# -> Font: TimesNewRomanPSMT, Size: 9.960000038146973
#
# Page 2: 'Kristin Archick '
# -> Font: Calibri-Bold, Size: 9.0
#
# Page 2: 'Specialist in European '
# -> Font: Calibri, Size: 9.0
#
# Page 2: 'Affairs '
# -> Font: Calibri, Size: 9.0
#
# Page 2: '  '
# -> Font: Calibri, Size: 9.0
#
# Page 2: ' '
# -> Font: Calibri, Size: 8.520000457763672
#
# Page 3: 'The European Union: Questions and Answers '
# -> Font: Verdana-Italic, Size: 8.039999961853027
#
# Page 3: ' '
# -> Font: Verdana-Italic, Size: 8.039999961853027
#
# Page 3: 'Congressional Research Service '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 3: ' '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 3: 'Contents '
# -> Font: PalatinoLinotype-Bold, Size: 18.0
#
# Page 3: 'What Is the European Union?.......................................................................................................... 1'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'How Does the EU Work? ................................................................................................................ 1'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'How Is the EU Governed? ............................................................................................................... 2'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'What Is the Lisbon Treaty?.............................................................................................................. 3'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'What Are the Euro and the Eurozone? ............................................................................................ 4'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'Why and How Is the EU Enlarging? ............................................................................................... 6'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'Does the EU Have a Foreign Policy? .............................................................................................. 7'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'Does the EU Have a Defense Policy? ............................................................................................. 8'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'What Is the Relationship of the EU to NATO? ............................................................................... 9'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'What Is Justice and Home Affairs? ............................................................................................... 10'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'What Is the Schengen Area? .......................................................................................................... 10'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'Does the EU Have a Trade Policy and Process? ............................................................................ 11'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'How Do EU Countries and Citizens View the EU? ...................................................................... 12'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'What Is Brexit, and How Has It Affected the EU? ........................................................................ 14'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'How Might the EU Evolve in the Future? ..................................................................................... 15'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'Does the United States Have a Formal Relationship with the EU? ............................................... 16'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'Who Are U.S. Officials’ Counterparts in the EU? ......................................................................... 16'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'What Is the History of U.S.-EU Relations? ................................................................................... 17'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: 'What Is the Current State of U.S.-EU Relations? .......................................................................... 18'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: 'Figures '
# -> Font: PalatinoLinotype-Bold, Size: 14.039999961853027
#
# Page 3: ' '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: 'Figure A-1. European Union Member States and Candidates ....................................................... 22'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: '  '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: 'Appendixes '
# -> Font: PalatinoLinotype-Bold, Size: 14.039999961853027
#
# Page 3: 'Appendix. Map of the European Union and Aspirant Countries ................................................... 22'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: 'Contacts '
# -> Font: PalatinoLinotype-Bold, Size: 14.039999961853027
#
# Page 3: 'Author Information ........................................................................................................................ 22'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: Calibri, Size: 11.039999961853027
#
# Page 3: ' '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'The European Union: Questions and Answers '
# -> Font: Verdana-Italic, Size: 8.039999961853027
#
# Page 4: ' '
# -> Font: Verdana-Italic, Size: 8.039999961853027
#
# Page 4: 'Congressional Research Service  '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 4: ' '
# -> Font: Calibri, Size: 9.0
#
# Page 4: '1 '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 4: 'What Is the European Union? '
# -> Font: PalatinoLinotype-Bold, Size: 18.0
#
# Page 4: 'The European Union (EU) is a unique political and economic partnership that currently consists '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'of 27 member states (see the map in the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'Appendix'
# -> Font: TimesNewRomanPS-BoldMT, Size: 11.039999961853027
#
# Page 4: ').'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: '1'
# -> Font: TimesNewRomanPSMT, Size: 6.960000038146973
#
# Page 4: ' Built through a series of binding treaties, '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'the EU is the latest stage in a process of integration begun after World War II to promote peace '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'and economic recovery in Europe. Its founders hoped that by creating specified areas in which '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'member states agreed to share sovereignty—initially in coal and steel production, trade, and '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'nuclear energy—it would promote interdependence and make another war in Europe unthinkable. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'Since the 1950s, this European integration project has expanded to encompass other economic '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'sectors; a customs union; a single market in which capital, goods, services, and people move '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'freely; a common trade policy; a common agricultural policy; aspects of social and environmental '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'policy; and a common currency (the euro) that is used by 20 member states. EU members also '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'have taken steps toward political integration, with decisions to develop a Common Foreign and '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'Security Policy (CFSP) and efforts to promote cooperation in the area of Justice and Home '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'Affairs (JHA). Most EU members participate in the Schengen area of free movement, which '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'allows individuals to travel without passport checks among most European countries. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'The EU is generally considered a cornerstone of European stability and prosperity, but it faces a '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'number of challenges. Although the EU has demonstrated solidarity in responding to Russia’s war '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'against Ukraine (launched in February 2022), the conflict has contributed to high energy prices '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'and inflation in the EU and has long-term strategic implications for the bloc. Other key issues for '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'the EU include democratic backsliding in some member states, the presence of populist and to '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'some extent anti-EU political parties throughout the bloc, ongoing migration concerns, managing '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'relations with the United Kingdom (UK) following its exit from the EU in January 2020 ('
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'Brexit'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 11.039999961853027
#
# Page 4: '), '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'and addressing political and economic concerns posed by China. Renewing strong ties with the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'United States also has been a key EU priority following heightened tensions during the Trump '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'Administration. The overall tenor of U.S.-EU relations has improved under the Biden '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'Administration, and the two partners have cooperated closely in addressing Russia’s aggression in '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'Ukraine. U.S.-EU differences, however, persist on issues such as clean energy subsidies and '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'China and pose tests for the U.S.-EU partnership. This report serves as a primer on the EU and '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'discusses U.S.-EU relations that may be of interest to the 118'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'th'
# -> Font: TimesNewRomanPSMT, Size: 6.960000038146973
#
# Page 4: ' Congress. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'How Does the EU Work? '
# -> Font: PalatinoLinotype-Bold, Size: 18.0
#
# Page 4: 'EU member states work together through common institutions (see “How Is the EU Governed?”) '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'to set policy and promote their collective interests. Decisionmaking processes and the role of the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'EU institutions differ depending on the subject under consideration. On a multitude of economic, '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'social, and internal security policies, member states have pooled their sovereignty to varying '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'degrees and EU institutions hold decisionmaking authority. EU legislation in such areas often has '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'a supranational quality, because it is subject to a complex majority voting system among member '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'states as well as European Parliament approval and is legally binding on member governments. In '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'certain other areas—especially foreign and security policy—member states have agreed to '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'cooperate but retain full sovereignty. Decisionmaking in such fields is intergovernmental and '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'requires the unanimous agreement of all EU countries; any one national government can veto a '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'decision. EU institutions generally play a more limited role in the decisionmaking process in such '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: 'policy areas but may be involved in implementation and oversight. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 4: ' '
# -> Font: TimesNewRomanPSMT, Size: 12.0
#
# Page 4: '1'
# -> Font: TimesNewRomanPSMT, Size: 6.0
#
# Page 4: ' The current 27 members of the EU are Austria, Belgium, Bulgaria, Croatia, Cyprus, the Czech Republic, Denmark, '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 4: 'Estonia, Finland, France, Germany, Greece, Hungary, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, the '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 4: 'Netherlands, Poland, Portugal, Romania, Slovakia, Slovenia, Spain, and Sweden. '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 5: 'The European Union: Questions and Answers '
# -> Font: Verdana-Italic, Size: 8.039999961853027
#
# Page 5: ' '
# -> Font: Verdana-Italic, Size: 8.039999961853027
#
# Page 5: 'Congressional Research Service  '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 5: ' '
# -> Font: Calibri, Size: 9.0
#
# Page 5: '2 '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 5: 'How Is the EU Governed? '
# -> Font: PalatinoLinotype-Bold, Size: 18.0
#
# Page 5: 'The EU is governed by several institutions that embody the EU’s dual supranational and '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'intergovernmental character: '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: '•'
# -> Font: SymbolMT, Size: 11.039999961853027
#
# Page 5: ' '
# -> Font: ArialMT, Size: 11.039999961853027
#
# Page 5: 'The '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'European Council'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 11.039999961853027
#
# Page 5: ' acts as the strategic guide for EU policy. It is composed of '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'the Heads of State or Government of the EU’s member states and the President of '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'the European Commission; it meets several times a year in what are often termed '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: '“EU summits.” The European Council is headed by a President, who organizes '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'the council’s work and facilitates consensus. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: '•'
# -> Font: SymbolMT, Size: 11.039999961853027
#
# Page 5: ' '
# -> Font: ArialMT, Size: 11.039999961853027
#
# Page 5: 'The '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'European Commission'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 11.039999961853027
#
# Page 5: ' upholds the common interest of the EU as a whole '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'and serves as the EU’s executive. It implements EU decisions and common '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'policies, ensures that the provisions of the EU’s treaties are carried out properly, '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'and has the sole right of legislative initiative in most policy areas. It is composed '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'of 27 Commissioners, one from each EU country. Commissioners serve five-year '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'terms; one Commissioner serves as European Commission President and the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'others hold distinct portfolios (e.g., agriculture, energy, trade). On many issues, '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'the European Commission handles negotiations with outside countries. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: '•'
# -> Font: SymbolMT, Size: 11.039999961853027
#
# Page 5: ' '
# -> Font: ArialMT, Size: 11.039999961853027
#
# Page 5: 'The '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'Council of the European Union '
# -> Font: TimesNewRomanPS-ItalicMT, Size: 11.039999961853027
#
# Page 5: '(also informally called the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'Council'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 11.039999961853027
#
# Page 5: ', or the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'Council of Ministers'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 11.039999961853027
#
# Page 5: ') represents the national governments. The Council of the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'EU enacts legislation, usually based on proposals put forward by the European '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'Commission and agreed to (in most cases) by the European Parliament. Different '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'ministers from each country participate in council meetings depending on the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'subject under consideration (e.g., foreign ministers would meet to discuss the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'Middle East, agriculture ministers to discuss farm subsidies). Most decisions are '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'subject to a complex majority voting system,'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: ' '
# -> Font: TimesNewRomanPSMT, Size: 6.960000038146973
#
# Page 5: 'but some areas—such as foreign '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'and defense policy, taxation, or accepting new members—require unanimity. The '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'Presidency of the Council of the EU rotates among the member states, changing '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'every six months; the country holding the Presidency helps set agenda priorities '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'and organizes most of the work of the Council of the EU. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: '•'
# -> Font: SymbolMT, Size: 11.039999961853027
#
# Page 5: ' '
# -> Font: ArialMT, Size: 11.039999961853027
#
# Page 5: 'The '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'European Parliament'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 11.039999961853027
#
# Page 5: ' represents the citizens of the EU. It currently has 705 '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'members who are directly elected for five-year terms (the most recent elections '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'were in May 2019; the next elections are due in June 2024). Each EU country has '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'a number of seats roughly proportional to the size of its population. Although the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'European Parliament cannot initiate legislation, it shares legislative power with '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'the Council of the EU in many policy areas, giving it the right to accept, amend, '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'or reject the majority of proposed EU legislation in a process known as the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: '“ordinary legislative procedure” or “co-decision.” The European Parliament also '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'decides on the allocation of the EU’s budget jointly with the Council of the EU. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'Members of the European Parliament (MEPs) caucus according to political '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'affiliation, rather than nationality; there are seven political groups and several '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'dozen nonattached MEPs in the European Parliament currently.'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: '2'
# -> Font: TimesNewRomanPSMT, Size: 6.960000038146973
#
# Page 5: ' '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'Other institutions also play key roles. The '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'Court of Justice'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 11.039999961853027
#
# Page 5: ' interprets EU laws, and its rulings are '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'binding; a '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'Court of Auditors'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 11.039999961853027
#
# Page 5: ' monitors financial management; the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'European Central Bank '
# -> Font: TimesNewRomanPS-ItalicMT, Size: 11.039999961853027
#
# Page 5: 'manages EU monetary policy and the euro; and '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'advisory committees'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 11.039999961853027
#
# Page 5: ' represent economic, social, '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: 'and regional interests. Also see the text box below on “Key EU Positions and Current Leaders.” '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 5: ' '
# -> Font: TimesNewRomanPSMT, Size: 12.0
#
# Page 5: '2'
# -> Font: TimesNewRomanPSMT, Size: 6.0
#
# Page 5: ' Also see CRS In Focus IF11211, '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 5: 'The European Parliament and U.S. Interests'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 9.0
#
# Page 5: ', by Kristin Archick. '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 6: 'The European Union: Questions and Answers '
# -> Font: Verdana-Italic, Size: 8.039999961853027
#
# Page 6: ' '
# -> Font: Verdana-Italic, Size: 8.039999961853027
#
# Page 6: 'Congressional Research Service  '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 6: ' '
# -> Font: Calibri, Size: 9.0
#
# Page 6: '3 '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 6: 'What Is the Lisbon Treaty? '
# -> Font: PalatinoLinotype-Bold, Size: 18.0
#
# Page 6: 'On December 1, 2009, the EU’s latest institutional reform endeavor—the Lisbon Treaty—came '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'into force following its ratification by all of the EU’s then-27 member states. It is the final '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'product of an effort begun in 2002 to reform the EU’s governing institutions and decisionmaking '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'processes. It amends, rather than replaces, the EU’s two core treaties—the Treaty on European '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'Union (TEU) and the Treaty on the Functioning of the EU (TFEU). Changes introduced by the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'Lisbon Treaty seek to '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: '•'
# -> Font: SymbolMT, Size: 11.039999961853027
#
# Page 6: ' '
# -> Font: ArialMT, Size: 11.039999961853027
#
# Page 6: 'enable the EU to function more effectively; '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: '•'
# -> Font: SymbolMT, Size: 11.039999961853027
#
# Page 6: ' '
# -> Font: ArialMT, Size: 11.039999961853027
#
# Page 6: 'enhance the EU’s role as a foreign policy actor; and '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: '•'
# -> Font: SymbolMT, Size: 11.039999961853027
#
# Page 6: ' '
# -> Font: ArialMT, Size: 11.039999961853027
#
# Page 6: 'increase democracy and transparency within the EU. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'To help accomplish these goals, the Lisbon Treaty established two new leadership positions: '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: '•'
# -> Font: SymbolMT, Size: 11.039999961853027
#
# Page 6: ' '
# -> Font: ArialMT, Size: 11.039999961853027
#
# Page 6: 'The President of the European Council, a single individual who chairs the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'meetings of the EU Heads of State or Government, serves as coordinator and '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'spokesman for their work, seeks to ensure policy continuity, and strives to forge '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'consensus among the member states.  '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: '•'
# -> Font: SymbolMT, Size: 11.039999961853027
#
# Page 6: ' '
# -> Font: ArialMT, Size: 11.039999961853027
#
# Page 6: 'A dual-hatted position of High Representative of the Union for Foreign Affairs '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'and Security Policy to serve essentially as the EU’s chief diplomat. The High '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'Representative is both an agent of the Council of the EU—and thus speaks for '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'the member states on foreign policy issues—as well as a Vice President of the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'European Commission, responsible for managing most of the commission’s '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'diplomatic activities and foreign assistance programs. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'Other key measures in the Lisbon Treaty included the following: '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: '•'
# -> Font: SymbolMT, Size: 11.039999961853027
#
# Page 6: ' '
# -> Font: ArialMT, Size: 11.039999961853027
#
# Page 6: 'Simplifying the EU’s qualified majority voting system and expanding its use to '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'policy areas previously subject to member state unanimity in the Council of the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'EU. This change was intended in part to speed EU decisionmaking, but member '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'states still tend to seek consensus as much as possible. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: '•'
# -> Font: SymbolMT, Size: 11.039999961853027
#
# Page 6: ' '
# -> Font: ArialMT, Size: 11.039999961853027
#
# Page 6: 'Increasing the relative power of the European Parliament by strengthening its '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'role in the EU’s budgetary process and extending the use of the “co-decision” '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'procedure to more policy areas, including agriculture and home affairs issues.'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: '3'
# -> Font: TimesNewRomanPSMT, Size: 6.960000038146973
#
# Page 6: ' As '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'such, the treaty gives the European Parliament a say equal to that of the member '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'states in the Council of the EU over the vast majority of EU legislation (with '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'some exceptions, such as most aspects of foreign and defense policy). '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'For the first time in the EU’s history, the Lisbon Treaty also introduced an “exit clause”—Article '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: '50 of the TEU—which outlines procedures for a member state to leave the EU. A member state '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'that decides to leave would invoke Article 50 by notifying the European Council of its intentions, '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'which would trigger a two-year period for withdrawal negotiations to be concluded; the EU may '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: 'also decide to extend the time for negotiations. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 6: ' '
# -> Font: TimesNewRomanPSMT, Size: 12.0
#
# Page 6: '3'
# -> Font: TimesNewRomanPSMT, Size: 6.0
#
# Page 6: ' The Lisbon Treaty technically renames the “co-decision” procedure as the “ordinary legislative procedure.” '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 7: 'The European Union: Questions and Answers '
# -> Font: Verdana-Italic, Size: 8.039999961853027
#
# Page 7: ' '
# -> Font: Verdana-Italic, Size: 8.039999961853027
#
# Page 7: 'Congressional Research Service  '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 7: ' '
# -> Font: Calibri, Size: 9.0
#
# Page 7: '4 '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 7: 'Key EU Positions and Current Leaders '
# -> Font: GillSansMT-Bold, Size: 11.039999961853027
#
# Page 7: 'The current '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'President of the European Council'
# -> Font: GillSansMT-BoldItalic, Size: 9.0
#
# Page 7: ' is Charles Michel, a former prime minister of Belgium. The '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'president is appointed by the member states for a 2½-year term (renewable once). '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'The current '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'President of the European Commission'
# -> Font: GillSansMT-BoldItalic, Size: 9.0
#
# Page 7: ' is Ursula von der Leyen of Germany, a former German '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'defense minister. The commission president is appointed by agreement among the member states, subject to the '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'approval of the European Parliament. In selecting the commission president, member states must take into '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'account the results of the most recent European Parliament elections. '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'Belgium holds the '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'Presidency of the Council of the EU'
# -> Font: GillSansMT-BoldItalic, Size: 9.0
#
# Page 7: ' (often termed the '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'EU Presidency'
# -> Font: GillSansMT-Italic, Size: 9.0
#
# Page 7: ') from January to June '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: '2024; Hungary will hold the presidency from July to December 2024. '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'Every 2½ years (twice per 5-year parliamentary term), Members of the European Parliament (MEPs) elect the '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'President of the European Parliament'
# -> Font: GillSansMT-BoldItalic, Size: 9.0
#
# Page 7: '. In January 2022, Maltese MEP Roberta Metsola was elected as president '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'of the European Parliament; Metsola is from the center-right European People’s Party parliamentary group. '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'The current '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'High Representative of the Union for Foreign Affairs and Security Policy'
# -> Font: GillSansMT-BoldItalic, Size: 9.0
#
# Page 7: ' is Josep Borrell of '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'Spain. The high representative is chosen by agreement among the member states but, like the other members of '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'the European Commission, must be approved by the European Parliament.  '
# -> Font: GillSansMT, Size: 9.0
#
# Page 7: 'What Are the Euro and the Eurozone? '
# -> Font: PalatinoLinotype-Bold, Size: 18.0
#
# Page 7: 'Twenty of the EU’s 27 member states use a common single currency, the euro, and are often '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'collectively referred to as “the eurozone.”'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: '4'
# -> Font: TimesNewRomanPSMT, Size: 6.960000038146973
#
# Page 7: ' The gradual introduction of the euro began in January '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: '1999 when 11 EU member states became the first to adopt it and banks and many businesses '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'started using the euro as a unit of account. Euro notes and coins replaced national currencies in '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'participating states in January 2002. Eurozone participants share a common central bank—the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'European Central Bank (ECB)—and a common monetary policy. However, they do not have a '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'common fiscal policy, and member states retain control over decisions about national spending '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'and taxation, subject to certain conditions designed to maintain budgetary discipline. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'In 2009-2010, a serious crisis in the eurozone developed, beginning in Greece. Over the previous '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'decade, the Greek government had borrowed heavily from international capital markets to pay for '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'its budget and trade deficits. As investors became increasingly nervous during 2009 about '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'Greece’s high sovereign (or public) debt level amid the global financial crisis, markets demanded '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'higher interest rates for Greek bonds, which drove up Greece’s borrowing costs. By early 2010, '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'Greece risked defaulting on its public debt. Market concerns quickly spread to several other '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'eurozone countries with high, potentially unsustainable levels of public debt, including Italy and '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'Spain (the eurozone’s third- and fourth-largest economies, respectively). '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'European leaders and EU institutions responded to the crisis and sought to stem its contagion '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'with a variety of policy mechanisms. To avoid default, Greece, Ireland, Portugal, and Cyprus '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'received loans from the EU and the International Monetary Fund (IMF) but were required to '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'impose strict austerity measures. Eurozone leaders also approved a recapitalization plan for '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'Spanish banks. Other key initiatives included creating a permanent EU financial assistance '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'facility (the European Stability Mechanism) to provide emergency support to eurozone countries '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'and a single bank supervisor for the eurozone, as well as ECB efforts to calm the financial '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'markets by purchasing large portions of European sovereign debt and providing significant '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: 'infusions of credit into the European banking system. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 7: ' '
# -> Font: TimesNewRomanPSMT, Size: 12.0
#
# Page 7: '4'
# -> Font: TimesNewRomanPSMT, Size: 6.0
#
# Page 7: ' The 20 members of the EU that use the euro are Austria, Belgium, Croatia, Cyprus, Estonia, Finland, France, '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 7: 'Germany, Greece, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, the Netherlands, Portugal, Slovakia, Slovenia, '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 7: 'and Spain. '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'The European Union: Questions and Answers '
# -> Font: Verdana-Italic, Size: 8.039999961853027
#
# Page 8: ' '
# -> Font: Verdana-Italic, Size: 8.039999961853027
#
# Page 8: 'Congressional Research Service  '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 8: ' '
# -> Font: Calibri, Size: 9.0
#
# Page 8: '5 '
# -> Font: ArialMT, Size: 8.039999961853027
#
# Page 8: 'The eurozone crisis began to abate in late 2012, as market confidence became more positive and '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'the situation started to stabilize in most eurozone countries. Ireland exited the EU-IMF financial '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'assistance program in 2013; Portugal did so in 2014, and Cyprus did so in 2016. EU aid to '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'Spanish banks ceased in 2014. Nevertheless, many EU member states continued to experience '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'weak economic growth and high unemployment. Greece’s economy and banking system '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'remained in particular distress. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'In the first half of 2015, prospects grew that Greece might exit the eurozone (dubbed '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'Grexit'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 11.039999961853027
#
# Page 8: ') as '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'the Greek government sought further financial aid from its eurozone creditors but also demanded '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'debt relief and an easing of austerity. For months, negotiations foundered. In June 2015, Greece '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'failed to make a payment to the IMF, and the government closed the banks and imposed capital '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'controls. In July 2015, however, the Greek government acceded to EU demands for more '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'austerity and economic reforms in exchange for the badly needed financial assistance. Between '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: '2010 and 2018, Greece received a total of $330 billion in loans from the EU, the ECB, and the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'IMF.'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: '5'
# -> Font: TimesNewRomanPSMT, Size: 6.960000038146973
#
# Page 8: ' Greece officially exited the EU-IMF financial assistance program in August 2018. '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'From its start, the eurozone crisis generated tensions among member states over the proper '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'balance between imposing austerity measures and stimulating growth and the need for greater EU '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'fiscal integration. Traditionally fiscally conservative member states, including Germany and the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'Netherlands, largely opposed integration steps that might lead to “bailing out” more indebted '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'countries in the future. Eurozone leaders have discussed additional measures to improve the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'eurozone’s economic governance and stability, but proposals such as establishing a common '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'eurozone budget have long been controversial.'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: '6'
# -> Font: TimesNewRomanPSMT, Size: 6.960000038146973
#
# Page 8: ' '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'Some analysts suggest the EU’s response to the economic crisis resulting from the Coronavirus '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'Disease 2019 (COVID-19) pandemic could open the door to further EU economic integration. In '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'July 2020, EU leaders (acting in the European Council) reached political agreement on a €750 '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'billion recovery fund consisting of both grants and loans for member states, attached to a €1.1 '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'trillion EU budget for 2021-2027.'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: '7'
# -> Font: TimesNewRomanPSMT, Size: 6.960000038146973
#
# Page 8: ' Financing for the COVID-19 recovery fund includes the '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'unprecedented issuing of EU bonds backed jointly by member states. Many EU officials, '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'including ECB President Christine Lagarde, maintained that the COVID-19 recovery plan—and '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'issuing common EU debt—represented a “one-off response to exceptional circumstances.”'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: '8'
# -> Font: TimesNewRomanPSMT, Size: 6.960000038146973
#
# Page 8: ' Some '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'in the EU suggest that common EU borrowing should be considered to deal with new challenges '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'such as the economic shocks caused by Russia’s war in Ukraine, financing Ukraine’s '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'reconstruction in the longer term, or supporting EU industries and innovation viewed as key to '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'the bloc’s future competitiveness and clean energy transition. Germany and other fiscally '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: 'conservative member states remain opposed to additional common borrowing.'
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: '9'
# -> Font: TimesNewRomanPSMT, Size: 6.960000038146973
#
# Page 8: ' '
# -> Font: TimesNewRomanPSMT, Size: 11.039999961853027
#
# Page 8: ' '
# -> Font: TimesNewRomanPSMT, Size: 12.0
#
# Page 8: '5'
# -> Font: TimesNewRomanPSMT, Size: 6.0
#
# Page 8: ' Bart Oosterveld and Alexatrini Tsiknia, “This Greek Tragedy Is Not Over Just Yet,” Atlantic Council, August 21, '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: '2018. '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: '6'
# -> Font: TimesNewRomanPSMT, Size: 6.0
#
# Page 8: ' Sam Fleming and Mehreen Khan, “EU Finance Ministers Approve Separate ‘Eurozone Budget’ Tool,” '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'Financial '
# -> Font: TimesNewRomanPS-ItalicMT, Size: 9.0
#
# Page 8: 'Times'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 9.0
#
# Page 8: ', October 10, 2019; Magnus G. Schoeller, “Preventing the EU Budget: Issue Replacement and Small State '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'Influence in the EMU,” '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'Journal of European Public Policy'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 9.0
#
# Page 8: ', July 24, 2020. '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: '7'
# -> Font: TimesNewRomanPSMT, Size: 6.0
#
# Page 8: ' European Commission, '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'The 2021-2027 EU Budget – What’s New?'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 9.0
#
# Page 8: ', at https://ec.europa.eu/info/strategy/eu-budget/'
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'long-term-eu-budget/2021-2027/whats-new_en. The EU formally approved the 2021-2027 budget in December 2020 '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'and finalized the recovery fund in February 2021. '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: '8'
# -> Font: TimesNewRomanPSMT, Size: 6.0
#
# Page 8: ' As quoted in Bjarke Smith-Meyer, “European Central Bank President Dismisses News Reports and Calls the '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'Pandemic Recovery Fund a One-off,” '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'Politico Europe'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 9.0
#
# Page 8: ', September 28, 2020. '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: '9'
# -> Font: TimesNewRomanPSMT, Size: 6.0
#
# Page 8: ' Jacob Funk Kirkegaard, “Will the Russia-Ukraine War Speed European Fiscal Integration?,” Peterson Institute for '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'International Economics, May 30, 2022; Jorge Valero and Jillian Deutsch, “EU Should Seek Joint Borrowing for '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'Ukraine Impact, Official Says,” Bloomberg.com, June 30, 2022; European Council President Charles Michel, “Going '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'Big for EU Industry,” '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'Politico Europe'
# -> Font: TimesNewRomanPS-ItalicMT, Size: 9.0
#
# Page 8: ', January 15, 2023; Maria Martinez and Jan Strupczewski, “Germany Dashes '
# -> Font: TimesNewRomanPSMT, Size: 9.0
#
# Page 8: 'Hopes for New EU Common Borrowing,” Reuters, February 16, 2023. '
# -> Font: TimesNewRomanPSMT, Size: 9.0

# %% [markdown]
# 1.1 You can create your **index**: check all your titles and paragraphs here and their respective pdf number.
# > This is being saved in your folder as well!

# %%
title_index, paragraph_index = show_your_index(all_docs_pdf, folder_path)

# %%
title_index # after running this, you can click in your little calculator for a better visualization
# Out:
#                                                Titles  Doc_IDs
# 0                            Updated January 26, 2024        0
# 1                                             SUMMARY        0
# 2                                             RS21372        0
# 3                         What Is the European Union?        0
# 4                               How Does the EU Work?        0
# 5                             How Is the EU Governed?        0
# 6                          What Is the Lisbon Treaty?        0
# 7                Key EU Positions and Current Leaders        0
# 8                 What Are the Euro and the Eurozone?        0
# 9                    Why and How Is the EU Enlarging?        0
# 10                 Does the EU Have a Foreign Policy?        0
# 11                 Does the EU Have a Defense Policy?        0
# 12        What Is the Relationship of the EU to NATO?        0
# 13                  What Is Justice and Home Affairs?        0
# 14                         What Is the Schengen Area?        0
# 15       Does the EU Have a Trade Policy and Process?        0
# 16      How Do EU Countries and Citizens View the EU?        0
# 17  What Is Brexit, and How Has It Affected the EU?31        0
# 18             How Might the EU Evolve in the Future?        0
# 19  Does the United States Have a Formal Relations...        0
# 20    Who Are U.S. Officials’ Counterparts in the EU?        0
# 21          What Is the History of U.S.-EU Relations?        0
# 22    What Is the Current State of U.S.-EU Relations?        0
# 23                                         Disclaimer        0

# %%
paragraph_index
# Out:
#                                            Paragraphs  Doc_IDs  \
# 0   Congressional Research Service https://crsrepo...        0
# 1                                             RS21372        0
# 2   The European Union (EU) is a political and eco...        0
# 3   How the EU Works The EU has been built through...        0
# 4   Challenges Facing the EU The EU is generally c...        0
# ..                                                ...      ...
# 91  Managing relations with China also may test U....        0
# 92  Additionally, both the United States and the E...        0
# 93  Israel-Hamas cease fire and on managing the co...        0
# 94  Moreover, EU concerns exist about ongoing U.S....        0
# 95  This document was prepared by the Congressiona...        0
#
#                                              Titles
# 0                          Updated January 26, 2024
# 1                          Updated January 26, 2024
# 2                                           SUMMARY
# 3                                           SUMMARY
# 4                                           SUMMARY
# ..                                              ...
# 91  What Is the Current State of U.S.-EU Relations?
# 92  What Is the Current State of U.S.-EU Relations?
# 93  What Is the Current State of U.S.-EU Relations?
# 94  What Is the Current State of U.S.-EU Relations?
# 95                                       Disclaimer
#
# [96 rows x 3 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 2. **Select** which text you want to give to your LLM.
#
#   * mode = "manually":
#     - by == "doc": You can selected full documents by giving doc_ids;
#     - by == "title": You can select text of certain titles, by giving the titles (as they appear in *title_index").
#     - by == "paragraph": You can select specific paragraphs, by giving their respective *index* number (column *index* in *paragraph_index*)
#
#     > "manually" mode needs a *to_select* to be defined (with the ids, titles or index number to collect)
#
#   * mode = "ranking": (only keyword-search w/ BM25)
#     - by == "title": automatically select the most relevant text based on the relevance of the titles with respect to your question. Returns the text of the titles that better matched your question.
#     - by == "paragraph": automatically select the most relevant text based on the relevance of the paragraphs with respect to your question. Returns the individual paragraphs that better matched your question.
#
#     > "ranking" mode needs a question to be defined, along with the number of results you want to retrieve (e.g: N=3, will retrieve the top 3)
#
#
#
#   **DON'T USE RANKING WHEN** you have a very little number of titles or paragraphs. BM25 will not work that well with a small dataset.
#
#
#   > (because it relies also on the ferquency of each word across all documents (here titles or paragraphs) to define its importance. If a word appears in all of the,, it's because is a general non-relevant word. Thus, if you only have one title/paragraph in your pdf(s), all words will be considered irrelevant and the scores will be negative ("No matches found").

# %%
to_select = [0, 1, 2]
mode = "manually"
by = "paragraph"
selected_text = select(all_docs_pdf, to_select, title_index, paragraph_index, mode=mode, by=by)
# Out:
#  Selected text:
#
# Congressional Research Service https://crsreports.congress.gov
#
#
# RS21372
#
#
# The European Union (EU) is a political and economic partnership that represents a unique form of
# cooperation among sovereign countries. The EU is the latest stage in a process of integration begun
# after World War II, initially by six Western European countries, to foster interdependence and make
# another war in Europe unthinkable. The EU currently consists of 27 member states, including most of
# the countries of Central and Eastern Europe, and has helped to promote peace, stability, and
# economic prosperity throughout the European continent.
#
#
#
#  Estimated number of tokens: 122.66666666666667

# %%
to_select = []
mode = "ranking"
by = "paragraph"
question = "What is the Schengen area?"
selected_text = select(all_docs_pdf, to_select, title_index,
                       paragraph_index, mode=mode, by=by, question=question, N=3)
# Out:
# Total time spent searching: 0.004138946533203125s
# 6.600	The Schengen area of free movement currently encompasses 23 EU member states plus 4 non-EU countries.24 Within the Schengen area, internal border controls have been eliminated, and individuals may travel without passport checks among participating countries. In effect, Schengen participants share a common external border where immigration checks for individuals entering or leaving the Schengen area are carried out. The Schengen area is founded upon the Schengen Agreement of 1985 (Schengen is the town in Luxembourg where the agreement was signed, originally by five countries). In 1999, the Schengen Agreement was incorporated into EU law. The Schengen Borders Code comprises a detailed set of rules governing both external and internal border controls in the Schengen area, including common rules on visas, asylum requests, and border checks. Participating countries may reintroduce internal border controls for a limited period of time in cases of a serious security threat or exceptional circumstances, such as a conference of world leaders or a major international sporting event.
#
# 5.841	Three EU countries (Bulgaria, Romania, and Cyprus) are not yet full Schengen members but have been working on meeting the necessary security and other requirements. In December 2023, EU member states approved Bulgaria and Romania’s partial entrance into the Schengen free movement area, starting with removing passport controls at internal air and sea borders from March 31, 2024; the EU plans to decide on lifting controls at internal land borders with Bulgaria and Romania at a later date.25 Ireland has an opt-out from the Schengen free movement area but takes part in some aspects of the Schengen Agreement related to police and judicial cooperation, including access to the SIS.
#
# 3.969	How the EU Works The EU has been built through a series of binding treaties. Over the years, EU member states have harmonized laws and adopted common policies on an increasing number of economic, social, and political issues. EU members share a customs union; a single market in which capital, goods, services, and people move freely; a common trade policy; and a common agricultural policy. Twenty EU member states use a common currency (the euro), and 23 members participate in the Schengen area of free movement in which internal border controls have been eliminated. In addition, the EU has been developing a Common Foreign and Security Policy (CFSP), which includes a Common Security and Defense Policy (CSDP), and pursuing cooperation in the area of Justice and Home Affairs (JHA) on common internal security challenges.
#
#  Selected text:
#
# The Schengen area of free movement currently encompasses 23 EU member states plus 4 non-EU
# countries.24 Within the Schengen area, internal border controls have been eliminated, and
# individuals may travel without passport checks among participating countries. In effect, Schengen
# participants share a common external border where immigration checks for individuals entering or
# leaving the Schengen area are carried out. The Schengen area is founded upon the Schengen Agreement
# of 1985 (Schengen is the town in Luxembourg where the agreement was signed, originally by five
# countries). In 1999, the Schengen Agreement was incorporated into EU law. The Schengen Borders Code
# comprises a detailed set of rules governing both external and internal border controls in the
# Schengen area, including common rules on visas, asylum requests, and border checks. Participating
# countries may reintroduce internal border controls for a limited period of time in cases of a
# serious security threat or exceptional circumstances, such as a conference of world leaders or a
# major international sporting event.
#
#
# Three EU countries (Bulgaria, Romania, and Cyprus) are not yet full Schengen members but have been
# working on meeting the necessary security and other requirements. In December 2023, EU member states
# approved Bulgaria and Romania’s partial entrance into the Schengen free movement area, starting with
# removing passport controls at internal air and sea borders from March 31, 2024; the EU plans to
# decide on lifting controls at internal land borders with Bulgaria and Romania at a later date.25
# Ireland has an opt-out from the Schengen free movement area but takes part in some aspects of the
# Schengen Agreement related to police and judicial cooperation, including access to the SIS.
#
#
# How the EU Works The EU has been built through a series of binding treaties. Over the years, EU
# member states have harmonized laws and adopted common policies on an increasing number of economic,
# social, and political issues. EU members share a customs union; a single market in which capital,
# goods, services, and people move freely; a common trade policy; and a common agricultural policy.
# Twenty EU member states use a common currency (the euro), and 23 members participate in the Schengen
# area of free movement in which internal border controls have been eliminated. In addition, the EU
# has been developing a Common Foreign and Security Policy (CFSP), which includes a Common Security
# and Defense Policy (CSDP), and pursuing cooperation in the area of Justice and Home Affairs (JHA) on
# common internal security challenges.
#
#
#
#  Estimated number of tokens: 546.6666666666666

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Use the LLM to do whatever you want.
#
# * Choose from hugging face wich LLM you want (model_id), create your token and load the model.
#
# **IMPORTANT:** Please pay attention to the maximum number of tokens your model allows (this should be written in the documentation of the model).
#
# > For example, here I chose to use one of the *gemma-2* models from hugging face. The maximum sequence length that this model might ever be used with is 8192 tokens [model's documentation](https://huggingface.co/docs/transformers/main/en/model_doc/gemma2).

# %%
token = 'your_token' #you'll need to get your own token from hugging face
model_id = "google/gemma-2-2b-it" # CHANGE this if you want to use another model

LLM = load_LLM_model(model_id, token)
# Out:
# config.json:   0%|          | 0.00/838 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/241M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/47.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]

# %% [markdown]
# * Write your own prompt instructions or use one of the ones bellow. Than you can select the one you want by the name you gave it:
#   *prompt_instructions[name_of_prompt]*

# %%
prompt_instructions = {
    # "name_of_prompt":
    # ''' Prompt instrutions '''

    "question_answering":
    '''Instructions: Using the provided web search results, write a comprehensive reply to the given query.
    Make sure to cite results using [number] notation after the reference.
    If the provided search results refer to multiple subjects with the same name, write separate answers for each subject.
    Be concise and to the point.'''
    ,

    "generate_queries":
    '''Instructions: What are some queries that should find the following results? List at least 5 unique queries, where at leats one for these documents would be better than others in an question-answering dataset.
    Be concise. Output only the list of queries and the corresponding results numbers that would be retrieved by each query, in the format "query - [n]".'''
    ,

    "summarize":
    '''

    '''
    ,

    }

# %% [markdown]
# * Check the full prompt and the estimated number of tokens to confirm that evrything is okay (total number of tokens should be < than the maximum allowed by the model you chose).

# %%
# Write here a question if you want to ask any to the model
# don't write anything, if you just want it to use the selected_text
# and your instructions
question = "What is the Schengen area?"

full_prompt = write_prompt(instructions=prompt_instructions["question_answering"],
                          context=selected_text,
                          question=question)
# Out:
# FULL PROMPT:
#  Instructions: Using the provided web search results, write a comprehensive reply to the given query.     Make sure to cite results using [number]
# notation after the reference.     If the provided search results refer to multiple subjects with the same name, write separate answers for each
# subject.     Be concise and to the point.         Web search results: [0] The Schengen area of free movement currently encompasses 23 EU member states
# plus 4 non-EU countries.24 Within the Schengen area, internal border controls have been eliminated, and individuals may travel without passport checks
# among participating countries. In effect, Schengen participants share a common external border where immigration checks for individuals entering or
# leaving the Schengen area are carried out. The Schengen area is founded upon the Schengen Agreement of 1985 (Schengen is the town in Luxembourg where
# the agreement was signed, originally by five countries). In 1999, the Schengen Agreement was incorporated into EU law. The Schengen Borders Code
# comprises a detailed set of rules governing both external and internal border controls in the Schengen area, including common rules on visas, asylum
# requests, and border checks. Participating countries may reintroduce internal border controls for a limited period of time in cases of a serious
# security threat or exceptional circumstances, such as a conference of world leaders or a major international sporting event. [1] Three EU countries
# (Bulgaria, Romania, and Cyprus) are not yet full Schengen members but have been working on meeting the necessary security and other requirements. In
# December 2023, EU member states approved Bulgaria and Romania’s partial entrance into the Schengen free movement area, starting with removing passport
# controls at internal air and sea borders from March 31, 2024; the EU plans to decide on lifting controls at internal land borders with Bulgaria and
# Romania at a later date.25 Ireland has an opt-out from the Schengen free movement area but takes part in some aspects of the Schengen Agreement
# related to police and judicial cooperation, including access to the SIS. [2] How the EU Works The EU has been built through a series of binding
# treaties. Over the years, EU member states have harmonized laws and adopted common policies on an increasing number of economic, social, and political
# issues. EU members share a customs union; a single market in which capital, goods, services, and people move freely; a common trade policy; and a
# common agricultural policy. Twenty EU member states use a common currency (the euro), and 23 members participate in the Schengen area of free movement
# in which internal border controls have been eliminated. In addition, the EU has been developing a Common Foreign and Security Policy (CFSP), which
# includes a Common Security and Defense Policy (CSDP), and pursuing cooperation in the area of Justice and Home Affairs (JHA) on common internal
# security challenges.          Query: What is the Schengen area?
#
#  ******* ESTIMATED NUMBER OF TOKENS: 630.6666666666666

# %% [markdown]
# * If everything is okay, you can now generate the answer to your prompt. You can select the temperature and maximum number of tokens (*max_length*) you want the model to return.
#   - temperature > 1: more creative response (changes the probabilities of the possible tokens to give more unlikely results)
#   - temperaure == 1 means regular sampling (uses the real probabilities)
#   - temperature == 0 means always answers with the most likely tokens.

# %%
answer = generative_response(LLM, full_prompt, temperature=1,
                        max_length=8000, instruction_tunned=True)
display(Markdown(answer))
# Out:
# The Schengen area is a zone within the European Union (EU) where internal border controls have been eliminated. This allows for free movement of people between participating countries.  The Schengen area comprises 23 EU member states plus 4 non-EU countries.  [0]
#
# The Schengen Agreement, signed in 1985 in Schengen, Luxembourg, established the framework for the area.  It was incorporated into EU law in 1999.  The Schengen Borders Code outlines rules governing both external and internal border controls, including visa requirements and asylum requests. [0]
#
# Participating countries can temporarily reintroduce internal border controls in specific circumstances, such as security threats or major events. [0]
#
# While Bulgaria, Romania, and Cyprus are not yet full Schengen members, they are working towards meeting the necessary requirements.  In December 2023, EU member states approved partial entry for Bulgaria and Romania, with passport controls at internal air and sea borders to be removed from March 31, 2024.  [1]
#
# Ireland has an opt-out from the Schengen free movement area but participates in some aspects of the Schengen Agreement related to police and judicial cooperation. [1]

# %% [markdown]
# And now you have your small prototype of a search-answer engine!
